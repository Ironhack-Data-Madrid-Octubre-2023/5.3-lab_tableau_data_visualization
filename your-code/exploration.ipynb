# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/nfl_football_team_stats.csv')

df.columns=[e.lower().replace(' ', '_') for e in df.columns]

# %%
df.head()
# Out:
#    year     date  gamenumber gamelocation                team  teamscore  \
# 0  2010   9/9/10           1         Away   Minnesota Vikings          9
# 1  2010   9/9/10           1         Home  New Orleans Saints         14
# 2  2010  9/12/10           1         Away   Arizona Cardinals         17
# 3  2010  9/12/10           1         Away     Atlanta Falcons          9
# 4  2010  9/12/10           1         Away   Carolina Panthers         18
#
#               opponent  oppponentscore result  passingattempts  ...  \
# 0   New Orleans Saints              14   Loss               27  ...
# 1    Minnesota Vikings               9    Win               36  ...
# 2       St. Louis Rams              13    Win               41  ...
# 3  Pittsburgh Steelers              15   Loss               44  ...
# 4      New York Giants              31   Loss               35  ...
#
#    kickreturntouchdowns  kickreturnyards  puntreturnattempts  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4093 entries, 0 to 4092
# Data columns (total 42 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   year                           4093 non-null   int64
#  1   date                           4093 non-null   object
#  2   gamenumber                     4093 non-null   int64
#  3   gamelocation                   4093 non-null   object
#  4   team                           4093 non-null   object
#  5   teamscore                      4093 non-null   int64
#  6   opponent                       4093 non-null   object
#  7   oppponentscore                 4093 non-null   int64
#  8   result                         4093 non-null   object
#  9   passingattempts                4093 non-null   int64
#  10  passingcompletions             4093 non-null   int64
#  11  passinginterceptions           4093 non-null   int64
# ...

# %%
df.describe().T
# Out:
#                                 count         mean        std     min     25%  \
# year                           4093.0  2013.345468   2.218045  2010.0  2011.0
# gamenumber                     4093.0     8.631810   4.813180     1.0     4.0
# teamscore                      4093.0    22.654776  10.166084     0.0    16.0
# oppponentscore                 4093.0    22.661862  10.160395     0.0    16.0
# passingattempts                4093.0    34.849743   8.617887     0.0    29.0
# passingcompletions             4093.0    21.512582   6.050266     0.0    17.0
# passinginterceptions           4093.0     0.909113   0.993649     0.0     0.0
# passerrating                   4093.0   100.924774  42.172779     0.0    74.8
# passingsacks                   4093.0     2.317371   1.706804     0.0     1.0
# passingsacksyardslost          4093.0    15.107256  12.479621     0.0     6.0
# passingtouchdowns              4093.0     1.535060   1.152605     0.0     1.0
# ...

# %%
df.year.unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])

# %%
df.groupby('year')['team' == 'Carolina Panthers'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/joaquin/Developer/5.3-lab_tableau_data_visualization/your-code/exploration.ipynb Celda 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/joaquin/Developer/5.3-lab_tableau_data_visualization/your-code/exploration.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> df.groupby('year')['team' == 'Carolina Panthers'].sum()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/groupby/generic.py:1964, in DataFrameGroupBy.__getitem__(self, key)
#    1957 if isinstance(key, tuple) and len(key) > 1:
#    1958     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1959     # valid syntax, so don't raise
#    1960     raise ValueError(
#    1961         "Cannot subset columns with a tuple with more than one element. "
#    1962         "Use a list instead."
#    1963     )
# ...
